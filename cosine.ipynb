# %% [markdown]
# <a href="https://colab.research.google.com/github/sugeethrao9/IOT-Assignment-521/blob/main/cosine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
review1="The movie was so fentastic ,I loved the acting and plot"
review2="The movie was so boring ,I hated the acting and plot"

# %%
def preprocess_text(text):
  tokens=word_tokenize(text)
  tokens=[word.lower() for word in tokens]
  stop_words=set(stopwords.words("english"))
  tokens=[word for word in tokens if word not in stop_words]
  lemmatizer=WordNetLemmatizer()
  tokens=[lemmatizer.lemmatize(word) for word in tokens]
  return " ".join(tokens)

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
vectors.toarray()
# Out:
# array([[0.37930349, 0.        , 0.53309782, 0.        , 0.53309782,
#         0.37930349, 0.37930349],
#        [0.37930349, 0.53309782, 0.        , 0.53309782, 0.        ,
#         0.37930349, 0.37930349]])

# %%
cosine_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosine_sim,3))
# Out:
# 0.432

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download("punkt_tab")
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
review1='The movie was so fentasic! the acting and plot by hero was good'
review2='movie was so boring ,I hated the acting and plot'

# %%
def preprocess_text(text):
  tokens=word_tokenize(text)
  tokens=[word.lower() for word in tokens]
  stop_words=set(stopwords.words("english"))
  tokens=[word for word in tokens if word not in stop_words]
  lemmatizer=WordNetLemmatizer()
  tokens=[lemmatizer.lemmatize(word) for word in tokens]
  return " ".join(tokens)

# %%
a=preprocess_text(review1)
print(a)
b=preprocess_text(review2)
print(b)
# Out:
# movie fentastic , loved acting plot
# movie boring , hated acting plot

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
vectors.toarray()
# Out:
# array([[0.37930349, 0.        , 0.53309782, 0.        , 0.53309782,
#         0.37930349, 0.37930349],
#        [0.37930349, 0.53309782, 0.        , 0.53309782, 0.        ,
#         0.37930349, 0.37930349]])

# %%
cosine_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosine_sim,3))
# Out:
# 0.432

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download("punkt_tab")
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
review1='The movie was so fentasic! the acting and plot by hero was good'
review2='movie was so boring ,I hated the acting and plot'

# %%
def preprocess_text(text):
  tokenize=word_tokenize(text)
  tokenize=[word.lower() for word in tokenize]
  stop_words=set(stopwords.words("english"))
  tokenize=[word for word in tokenize if word not in stop_words]
  lemmatizer=WordNetLemmatizer()
  tokenize=[lemmatizer.lemmatize(word) for word in tokenize]
  return " ".join(tokenize)

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)
print(a)
print(b)
# Out:
# movie fentastic , loved acting plot
# movie boring , hated acting plot

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
print(vectors.toarray())
# Out:
# [[0.37930349 0.         0.53309782 0.         0.53309782 0.37930349
#   0.37930349]
#  [0.37930349 0.53309782 0.         0.53309782 0.         0.37930349
#   0.37930349]]

# %%
cosin_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosin_sim,3))
# Out:
# 0.432
